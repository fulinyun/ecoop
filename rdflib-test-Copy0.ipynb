# %%
import rdflib
g = rdflib.Graph()
result = g.parse("http://www.w3.org/People/Berners-Lee/card")

print("graph has %s statements." % len(g))
# Out:
# graph has 86 statements.

# %%
for subj, pred, obj in g:
   if (subj, pred, obj) not in g:
       raise Exception("It better be!")

g.bind("foaf", FOAF)

s = g.serialize(format='n3')
print s
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a foaf:Person ;
#     foaf:mbox <mailto:donna@example.org> ;
#     foaf:name "Donna Fales" ;
#     foaf:nick "donna"@foo .

# %%
from rdflib import Graph, Literal, BNode, Namespace, RDF, URIRef
from rdflib.namespace import DC, FOAF

g = Graph()

# Create an identifier to use as the subject for Donna.
donna = BNode()

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print((s, p, o))
# Out:
# --- printing raw triples ---
# (rdflib.term.BNode('Nfc473418f5db4f04b2a72c2cf45ba918'), rdflib.term.URIRef(u'http://xmlns.com/foaf/0.1/nick'), rdflib.term.Literal(u'donna', lang='foo'))
# (rdflib.term.BNode('Nfc473418f5db4f04b2a72c2cf45ba918'), rdflib.term.URIRef(u'http://xmlns.com/foaf/0.1/name'), rdflib.term.Literal(u'Donna Fales'))
# (rdflib.term.BNode('Nfc473418f5db4f04b2a72c2cf45ba918'), rdflib.term.URIRef(u'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef(u'http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.BNode('Nfc473418f5db4f04b2a72c2cf45ba918'), rdflib.term.URIRef(u'http://xmlns.com/foaf/0.1/mbox'), rdflib.term.URIRef(u'mailto:donna@example.org'))

# %%
# For each foaf:Person in the store print out its mbox property.
print("--- printing mboxes ---")
for person in g.subjects(RDF.type, FOAF.Person):
    for mbox in g.objects(person, FOAF.mbox):
        print(mbox)
# Out:
# --- printing mboxes ---
# mailto:donna@example.org

# %%
# Bind a few prefix, namespace pairs for more readable output
g.bind("dc", DC)
g.bind("foaf", FOAF)

print( g.serialize(format='n3') )
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a foaf:Person ;
#     foaf:mbox <mailto:donna@example.org> ;
#     foaf:name "Donna Fales" ;
#     foaf:nick "donna"@foo .

# %%
g.load("http://danbri.livejournal.com/data/foaf")

for s,_,n in g.triples((None, FOAF['member_name'], None)):
    g.add((s, FOAF['name'], n))

print( g.serialize(format='n3') )
# Out:
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix lj: <http://www.livejournal.org/rss/lj/1.0/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ya: <http://blogs.yandex.ru/schema/foaf/> .
#
# <http://danbri.livejournal.com/data/http%3A%2F%2Fdanbri.org%2F> dc:title ""@en .
#
# <http://danbri.livejournal.com/data/rss> dc:type "application/rss+xml"@en .
#
# <http://danbri.livejournal.com/profile> a foaf:Document ;
#     dc:description "Full LiveJournal.com profile, including information such as interests and bio."@en ;
#     dc:title "LiveJournal.com Profile"@en .
#
# <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK> dc:title "UK"@en .
#
# <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK&loc_st=&loc_ci=Bristol> dc:title "Bristol"@en .
#
# <http://www.livejournal.com/interests.bml?int=activism> dc:title "activism"@en .
#
# <http://www.livejournal.com/interests.bml?int=bristol> dc:title "bristol"@en .
#
# <http://www.livejournal.com/interests.bml?int=foaf> dc:title "foaf"@en .
#
# <http://www.livejournal.com/interests.bml?int=human%20rights> dc:title "human rights"@en .
#
# <http://www.livejournal.com/interests.bml?int=internet%20tv> dc:title "internet tv"@en .
#
# <http://www.livejournal.com/interests.bml?int=politics> dc:title "politics"@en .
#
# <http://www.livejournal.com/interests.bml?int=rdf> dc:title "rdf"@en .
#
# <http://www.livejournal.com/interests.bml?int=semantic%20web> dc:title "semantic web"@en .
#
# <http://www.livejournal.com/interests.bml?int=standards> dc:title "standards"@en .
#
# <http://www.livejournal.com/interests.bml?int=technology> dc:title "technology"@en .
#
# <http://www.livejournal.com/interests.bml?int=web> dc:title "web"@en .
#
# <http://www.livejournal.com/interests.bml?int=widgets> dc:title "widgets"@en .
#
# <http://www.livejournal.com/interests.bml?int=xml> dc:title "xml"@en .
#
# <http://danbri.livejournal.com/> lj:dateCreated "2003-09-23T12:20:50"@en ;
#     lj:dateLastUpdated "2012-02-09T17:34:53"@en .
#
# [] a foaf:Person ;
#     ya:blogActivity [ a ya:Posts ;
#             ya:feed <http://danbri.livejournal.com/data/rss> ;
#             ya:posted "14"@en ] ;
#     ya:city <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK&loc_st=&loc_ci=Bristol> ;
#     ya:country <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK> ;
#     foaf:aimChatID "danbri2002"@en ;
#     foaf:dateOfBirth "1972-01-09"@en ;
#     foaf:homepage <http://danbri.livejournal.com/data/http%3A%2F%2Fdanbri.org%2F> ;
#     foaf:icqChatID ""@en ;
#     foaf:img <http://l-userpic.livejournal.com/68202348/1344540> ;
#     foaf:interest <http://www.livejournal.com/interests.bml?int=activism>,
#         <http://www.livejournal.com/interests.bml?int=bristol>,
#         <http://www.livejournal.com/interests.bml?int=foaf>,
#         <http://www.livejournal.com/interests.bml?int=human%20rights>,
#         <http://www.livejournal.com/interests.bml?int=internet%20tv>,
#         <http://www.livejournal.com/interests.bml?int=politics>,
#         <http://www.livejournal.com/interests.bml?int=rdf>,
#         <http://www.livejournal.com/interests.bml?int=semantic%20web>,
#         <http://www.livejournal.com/interests.bml?int=standards>,
#         <http://www.livejournal.com/interests.bml?int=technology>,
#         <http://www.livejournal.com/interests.bml?int=web>,
#         <http://www.livejournal.com/interests.bml?int=widgets>,
#         <http://www.livejournal.com/interests.bml?int=xml> ;
#     foaf:jabberID "danbri@jabber.com"@en ;
#     foaf:knows [ a foaf:Person ;
#             rdfs:seeAlso <http://anjeve.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54077021/20017"@en ;
#             foaf:member_name "anjeve"@en ;
#             foaf:name "anjeve"@en ;
#             foaf:nick "anjeve"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://anjeve.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://johnromkey.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/113692286/5816918"@en ;
#             foaf:member_name "johnromkey"@en ;
#             foaf:name "johnromkey"@en ;
#             foaf:nick "johnromkey"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://johnromkey.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://crschmidt.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/80589366/627594"@en ;
#             foaf:member_name "Chris Schmidt"@en ;
#             foaf:name "Chris Schmidt"@en ;
#             foaf:nick "crschmidt"@en ;
#             foaf:tagLine "Christopher Schmidt"@en ;
#             foaf:weblog <http://crschmidt.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://daveman692.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/46843689/1356357"@en ;
#             foaf:member_name "David Recordon"@en ;
#             foaf:name "David Recordon"@en ;
#             foaf:nick "daveman692"@en ;
#             foaf:tagLine "David Recordon's (Old) Blog"@en ;
#             foaf:weblog <http://daveman692.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://brad.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54541970/2"@en ;
#             foaf:member_name "Brad Fitzpatrick"@en ;
#             foaf:name "Brad Fitzpatrick"@en ;
#             foaf:nick "brad"@en ;
#             foaf:tagLine "brad's life"@en ;
#             foaf:weblog <http://brad.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://thesliver.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/3811411/3062"@en ;
#             foaf:member_name "Sliver"@en ;
#             foaf:name "Sliver"@en ;
#             foaf:nick "thesliver"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://thesliver.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://jsmarr.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/65162517/13190989"@en ;
#             foaf:member_name "Joseph Smarr"@en ;
#             foaf:name "Joseph Smarr"@en ;
#             foaf:nick "jsmarr"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://jsmarr.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://missmhart.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/82994154/2242523"@en ;
#             foaf:member_name "missmhart"@en ;
#             foaf:name "missmhart"@en ;
#             foaf:nick "missmhart"@en ;
#             foaf:tagLine "Mags' Musings"@en ;
#             foaf:weblog <http://missmhart.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://danja.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/47976318/288760"@en ;
#             foaf:member_name "ДарьБорисссна"@en ;
#             foaf:name "ДарьБорисссна"@en ;
#             foaf:nick "danja"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://danja.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://quercus.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/1908057/581109"@en ;
#             foaf:member_name "Dingbat"@en ;
#             foaf:name "Dingbat"@en ;
#             foaf:nick "quercus"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://quercus.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://sandhawke.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/28466290/586448"@en ;
#             foaf:member_name "Sandro"@en ;
#             foaf:name "Sandro"@en ;
#             foaf:nick "sandhawke"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://sandhawke.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://nmh.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/119226/97764"@en ;
#             foaf:member_name "goat"@en ;
#             foaf:name "goat"@en ;
#             foaf:nick "nmh"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://nmh.livejournal.com/> ] ;
#     foaf:msnChatID "danbri@hotmail.co.uk"@en ;
#     foaf:name "Dan Brickley"@en ;
#     foaf:nick "danbri"@en ;
#     foaf:openid <http://danbri.livejournal.com/> ;
#     foaf:page <http://danbri.livejournal.com/profile> ;
#     foaf:weblog <http://danbri.livejournal.com/> ;
#     foaf:yahooChatID "danbri3"@en .
#
# [] a foaf:Person ;
#     ya:blogActivity [ a ya:Posts ;
#             ya:feed <http://danbri.livejournal.com/data/rss> ;
#             ya:posted "14"@en ] ;
#     ya:city <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK&loc_st=&loc_ci=Bristol> ;
#     ya:country <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK> ;
#     foaf:aimChatID "danbri2002"@en ;
#     foaf:dateOfBirth "1972-01-09"@en ;
#     foaf:homepage <http://danbri.livejournal.com/data/http%3A%2F%2Fdanbri.org%2F> ;
#     foaf:icqChatID ""@en ;
#     foaf:img <http://l-userpic.livejournal.com/68202348/1344540> ;
#     foaf:interest <http://www.livejournal.com/interests.bml?int=activism>,
#         <http://www.livejournal.com/interests.bml?int=bristol>,
#         <http://www.livejournal.com/interests.bml?int=foaf>,
#         <http://www.livejournal.com/interests.bml?int=human%20rights>,
#         <http://www.livejournal.com/interests.bml?int=internet%20tv>,
#         <http://www.livejournal.com/interests.bml?int=politics>,
#         <http://www.livejournal.com/interests.bml?int=rdf>,
#         <http://www.livejournal.com/interests.bml?int=semantic%20web>,
#         <http://www.livejournal.com/interests.bml?int=standards>,
#         <http://www.livejournal.com/interests.bml?int=technology>,
#         <http://www.livejournal.com/interests.bml?int=web>,
#         <http://www.livejournal.com/interests.bml?int=widgets>,
#         <http://www.livejournal.com/interests.bml?int=xml> ;
#     foaf:jabberID "danbri@jabber.com"@en ;
#     foaf:knows [ a foaf:Person ;
#             rdfs:seeAlso <http://crschmidt.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/80589366/627594"@en ;
#             foaf:member_name "Chris Schmidt"@en ;
#             foaf:name "Chris Schmidt"@en ;
#             foaf:nick "crschmidt"@en ;
#             foaf:tagLine "Christopher Schmidt"@en ;
#             foaf:weblog <http://crschmidt.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://brad.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54541970/2"@en ;
#             foaf:member_name "Brad Fitzpatrick"@en ;
#             foaf:name "Brad Fitzpatrick"@en ;
#             foaf:nick "brad"@en ;
#             foaf:tagLine "brad's life"@en ;
#             foaf:weblog <http://brad.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://daveman692.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/46843689/1356357"@en ;
#             foaf:member_name "David Recordon"@en ;
#             foaf:name "David Recordon"@en ;
#             foaf:nick "daveman692"@en ;
#             foaf:tagLine "David Recordon's (Old) Blog"@en ;
#             foaf:weblog <http://daveman692.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://johnromkey.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/113692286/5816918"@en ;
#             foaf:member_name "johnromkey"@en ;
#             foaf:name "johnromkey"@en ;
#             foaf:nick "johnromkey"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://johnromkey.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://quercus.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/1908057/581109"@en ;
#             foaf:member_name "Dingbat"@en ;
#             foaf:name "Dingbat"@en ;
#             foaf:nick "quercus"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://quercus.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://missmhart.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/82994154/2242523"@en ;
#             foaf:member_name "missmhart"@en ;
#             foaf:name "missmhart"@en ;
#             foaf:nick "missmhart"@en ;
#             foaf:tagLine "Mags' Musings"@en ;
#             foaf:weblog <http://missmhart.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://jsmarr.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/65162517/13190989"@en ;
#             foaf:member_name "Joseph Smarr"@en ;
#             foaf:name "Joseph Smarr"@en ;
#             foaf:nick "jsmarr"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://jsmarr.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://danja.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/47976318/288760"@en ;
#             foaf:member_name "ДарьБорисссна"@en ;
#             foaf:name "ДарьБорисссна"@en ;
#             foaf:nick "danja"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://danja.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://thesliver.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/3811411/3062"@en ;
#             foaf:member_name "Sliver"@en ;
#             foaf:name "Sliver"@en ;
#             foaf:nick "thesliver"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://thesliver.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://nmh.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/119226/97764"@en ;
#             foaf:member_name "goat"@en ;
#             foaf:name "goat"@en ;
#             foaf:nick "nmh"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://nmh.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://anjeve.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54077021/20017"@en ;
#             foaf:member_name "anjeve"@en ;
#             foaf:name "anjeve"@en ;
#             foaf:nick "anjeve"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://anjeve.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://sandhawke.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/28466290/586448"@en ;
#             foaf:member_name "Sandro"@en ;
#             foaf:name "Sandro"@en ;
#             foaf:nick "sandhawke"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://sandhawke.livejournal.com/> ] ;
#     foaf:msnChatID "danbri@hotmail.co.uk"@en ;
#     foaf:name "Dan Brickley"@en ;
#     foaf:nick "danbri"@en ;
#     foaf:openid <http://danbri.livejournal.com/> ;
#     foaf:page <http://danbri.livejournal.com/profile> ;
#     foaf:weblog <http://danbri.livejournal.com/> ;
#     foaf:yahooChatID "danbri3"@en .
#
# [] a foaf:Person ;
#     ya:blogActivity [ a ya:Posts ;
#             ya:feed <http://danbri.livejournal.com/data/rss> ;
#             ya:posted "14"@en ] ;
#     ya:city <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK&loc_st=&loc_ci=Bristol> ;
#     ya:country <http://www.livejournal.com/directory.bml?opt_sort=ut&s_loc=1&loc_cn=UK> ;
#     foaf:aimChatID "danbri2002"@en ;
#     foaf:dateOfBirth "1972-01-09"@en ;
#     foaf:homepage <http://danbri.livejournal.com/data/http%3A%2F%2Fdanbri.org%2F> ;
#     foaf:icqChatID ""@en ;
#     foaf:img <http://l-userpic.livejournal.com/68202348/1344540> ;
#     foaf:interest <http://www.livejournal.com/interests.bml?int=activism>,
#         <http://www.livejournal.com/interests.bml?int=bristol>,
#         <http://www.livejournal.com/interests.bml?int=foaf>,
#         <http://www.livejournal.com/interests.bml?int=human%20rights>,
#         <http://www.livejournal.com/interests.bml?int=internet%20tv>,
#         <http://www.livejournal.com/interests.bml?int=politics>,
#         <http://www.livejournal.com/interests.bml?int=rdf>,
#         <http://www.livejournal.com/interests.bml?int=semantic%20web>,
#         <http://www.livejournal.com/interests.bml?int=standards>,
#         <http://www.livejournal.com/interests.bml?int=technology>,
#         <http://www.livejournal.com/interests.bml?int=web>,
#         <http://www.livejournal.com/interests.bml?int=widgets>,
#         <http://www.livejournal.com/interests.bml?int=xml> ;
#     foaf:jabberID "danbri@jabber.com"@en ;
#     foaf:knows [ a foaf:Person ;
#             rdfs:seeAlso <http://brad.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54541970/2"@en ;
#             foaf:member_name "Brad Fitzpatrick"@en ;
#             foaf:name "Brad Fitzpatrick"@en ;
#             foaf:nick "brad"@en ;
#             foaf:tagLine "brad's life"@en ;
#             foaf:weblog <http://brad.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://sandhawke.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/28466290/586448"@en ;
#             foaf:member_name "Sandro"@en ;
#             foaf:name "Sandro"@en ;
#             foaf:nick "sandhawke"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://sandhawke.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://anjeve.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/54077021/20017"@en ;
#             foaf:member_name "anjeve"@en ;
#             foaf:name "anjeve"@en ;
#             foaf:nick "anjeve"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://anjeve.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://quercus.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/1908057/581109"@en ;
#             foaf:member_name "Dingbat"@en ;
#             foaf:name "Dingbat"@en ;
#             foaf:nick "quercus"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://quercus.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://missmhart.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/82994154/2242523"@en ;
#             foaf:member_name "missmhart"@en ;
#             foaf:name "missmhart"@en ;
#             foaf:nick "missmhart"@en ;
#             foaf:tagLine "Mags' Musings"@en ;
#             foaf:weblog <http://missmhart.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://jsmarr.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/65162517/13190989"@en ;
#             foaf:member_name "Joseph Smarr"@en ;
#             foaf:name "Joseph Smarr"@en ;
#             foaf:nick "jsmarr"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://jsmarr.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://johnromkey.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/113692286/5816918"@en ;
#             foaf:member_name "johnromkey"@en ;
#             foaf:name "johnromkey"@en ;
#             foaf:nick "johnromkey"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://johnromkey.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://nmh.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/119226/97764"@en ;
#             foaf:member_name "goat"@en ;
#             foaf:name "goat"@en ;
#             foaf:nick "nmh"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://nmh.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://crschmidt.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/80589366/627594"@en ;
#             foaf:member_name "Chris Schmidt"@en ;
#             foaf:name "Chris Schmidt"@en ;
#             foaf:nick "crschmidt"@en ;
#             foaf:tagLine "Christopher Schmidt"@en ;
#             foaf:weblog <http://crschmidt.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://danja.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/47976318/288760"@en ;
#             foaf:member_name "ДарьБорисссна"@en ;
#             foaf:name "ДарьБорисссна"@en ;
#             foaf:nick "danja"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://danja.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://daveman692.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/46843689/1356357"@en ;
#             foaf:member_name "David Recordon"@en ;
#             foaf:name "David Recordon"@en ;
#             foaf:nick "daveman692"@en ;
#             foaf:tagLine "David Recordon's (Old) Blog"@en ;
#             foaf:weblog <http://daveman692.livejournal.com/> ],
#         [ a foaf:Person ;
#             rdfs:seeAlso <http://thesliver.livejournal.com/data/foaf> ;
#             foaf:image "http://l-userpic.livejournal.com/3811411/3062"@en ;
#             foaf:member_name "Sliver"@en ;
#             foaf:name "Sliver"@en ;
#             foaf:nick "thesliver"@en ;
#             foaf:tagLine ""@en ;
#             foaf:weblog <http://thesliver.livejournal.com/> ] ;
#     foaf:msnChatID "danbri@hotmail.co.uk"@en ;
#     foaf:name "Dan Brickley"@en ;
#     foaf:nick "danbri"@en ;
#     foaf:openid <http://danbri.livejournal.com/> ;
#     foaf:page <http://danbri.livejournal.com/profile> ;
#     foaf:weblog <http://danbri.livejournal.com/> ;
#     foaf:yahooChatID "danbri3"@en .
#
# [] a foaf:Person ;
#     foaf:mbox <mailto:donna@example.org> ;
#     foaf:name "Donna Fales" ;
#     foaf:nick "donna"@foo .
